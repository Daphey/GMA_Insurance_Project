# %%
# Import necessary Libraries and Dataset

import pandas as pd
import numpy as np

claims = pd.read_csv("data/claims.csv")
policyholders = pd.read_csv("data/policyholders.csv")
third_party = pd.read_csv("data/third_party.csv")

# Display the first few rows of each dataset to understand their structure
print("Claims Dataset:")
print(claims.head())
print("\nPolicyholders Dataset:")
print(policyholders.head())
print("\nThird Party Dataset:")
print(third_party.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Import necessary Libraries and Dataset
# ----> 3 import pandas as pd
#       4 import numpy as np
#       6 claims = pd.read_csv("data/claims.csv")
#
# ModuleNotFoundError: No module named 'pandas'
